# %%
import pandas as pd

# %%
data=[1,2,3,4,5]
index=['a','b','c','d','e']
series=pd.Series(data)
print(series)
series=pd.Series(data,index)
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
obesity_data=pd.read_csv('./obesity_prediction.csv')

# %%
obesity_data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  21.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3    no   2.0   no  2.0  0.0  Frequently                Walking
# 4    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
obesity_data.tail()
# Out:
#       Gender        Age    Height      Weight family_history FAVC  FCVC  NCP  \
# 2106  Female  20.976842  1.710730  131.408528            yes  yes   3.0  3.0
# 2107  Female  21.982942  1.748584  133.742943            yes  yes   3.0  3.0
# 2108  Female  22.524036  1.752206  133.689352            yes  yes   3.0  3.0
# 2109  Female  24.361936  1.739450  133.346641            yes  yes   3.0  3.0
# 2110  Female  23.664709  1.738836  133.472641            yes  yes   3.0  3.0
#
#            CAEC SMOKE      CH2O SCC       FAF       TUE       CALC  \
# 2106  Sometimes    no  1.728139  no  1.676269  0.906247  Sometimes
# 2107  Sometimes    no  2.005130  no  1.341390  0.599270  Sometimes
# 2108  Sometimes    no  2.054193  no  1.414209  0.646288  Sometimes
# 2109  Sometimes    no  2.852339  no  1.139107  0.586035  Sometimes
# 2110  Sometimes    no  2.863513  no  1.026452  0.714137  Sometimes
#
#                      MTRANS           Obesity
# 2106  Public_Transportation  Obesity_Type_III
# ...

# %%
obesity_data.sample()
# Out:
#     Gender     Age    Height     Weight family_history FAVC      FCVC  \
# 928   Male  19.627  1.815409  85.302146            yes  yes  2.987148
#
#           NCP       CAEC SMOKE      CH2O SCC       FAF       TUE       CALC  \
# 928  3.483449  Sometimes    no  2.359246  no  2.060415  0.598999  Sometimes
#
#                     MTRANS             Obesity
# 928  Public_Transportation  Overweight_Level_I

# %%
obesity_data.sample(10)
# Out:
#       Gender        Age    Height      Weight family_history FAVC      FCVC  \
# 1487  Female  39.126310  1.562889   76.659490            yes  yes  2.000000
# 1444  Female  23.652435  1.562724   80.535698            yes  yes  2.000000
# 705   Female  22.993680  1.741377   54.877111            yes  yes  3.000000
# 1377    Male  29.633715  1.834842  105.199360            yes  yes  2.805533
# 1633    Male  30.475248  1.801368  121.094257            yes  yes  2.328469
# 1787    Male  24.511445  1.852664  121.310257            yes  yes  2.906269
# 1888  Female  25.989938  1.644199  105.036075            yes  yes  3.000000
# 562   Female  17.000433  1.584951   44.411801             no  yes  2.737762
# 1938  Female  21.413498  1.719900  133.886031            yes  yes  3.000000
# 1290    Male  22.975526  1.701986   95.000000            yes  yes  2.000000
#
#            NCP        CAEC SMOKE      CH2O SCC       FAF       TUE       CALC  \
# ...

# %%
obesity_data.sample(10,random_state=30)
# Out:
#       Gender        Age    Height      Weight family_history FAVC      FCVC  \
# 6     Female  23.000000  1.500000   55.000000            yes  yes  3.000000
# 1077  Female  23.728707  1.663509   80.000000            yes  yes  2.000000
# 2100  Female  25.777565  1.628205  107.378702            yes  yes  3.000000
# 1618    Male  41.000000  1.750000  115.806977            yes  yes  2.000000
# 1347    Male  22.352025  1.754711  105.000706            yes  yes  2.871137
# 620   Female  19.931667  1.653209   49.026214             no   no  2.530066
# 1276    Male  19.089595  1.700164   99.204695            yes  yes  2.000000
# 1381  Female  33.226808  1.557943   77.647716            yes  yes  2.020910
# 353   Female  24.000000  1.600000   51.000000            yes  yes  1.000000
# 220   Female  21.000000  1.750000   78.000000            yes   no  2.000000
#
#            NCP        CAEC SMOKE      CH2O  SCC       FAF       TUE  \
# ...

# %%
obesity_data.columns.tolist()
# Out:
# ['Gender',
#  'Age',
#  'Height',
#  'Weight',
#  'family_history',
#  'FAVC',
#  'FCVC',
#  'NCP',
#  'CAEC',
#  'SMOKE',
#  'CH2O',
#  'SCC',
#  'FAF',
#  'TUE',
#  'CALC',
#  'MTRANS',
#  'Obesity']

# %%
obesity_data.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %%
obesity_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          2111 non-null   object
#  1   Age             2111 non-null   float64
#  2   Height          2111 non-null   float64
#  3   Weight          2111 non-null   float64
#  4   family_history  2111 non-null   object
#  5   FAVC            2111 non-null   object
#  6   FCVC            2111 non-null   float64
#  7   NCP             2111 non-null   float64
#  8   CAEC            2111 non-null   object
#  9   SMOKE           2111 non-null   object
#  10  CH2O            2111 non-null   float64
#  11  SCC             2111 non-null   object
#  12  FAF             2111 non-null   float64
#  13  TUE             2111 non-null   float64
#  14  CALC            2111 non-null   object
#  15  MTRANS          2111 non-null   object
#  16  Obesity         2111 non-null   object
# ...

# %%
obesity_data.loc[[0],['Age']]
# Out:
#     Age
# 0  21.0

# %%
obesity_data.loc[[0,10],['Age']]
# Out:
#      Age
# 0   21.0
# 10  26.0

# %%
obesity_data.loc[0:10 ,['Age']]
# Out:
#      Age
# 0   21.0
# 1   21.0
# 2   23.0
# 3   27.0
# 4   22.0
# 5   29.0
# 6   23.0
# 7   22.0
# 8   24.0
# 9   22.0
# 10  26.0

# %%
obesity_data.loc[0:10 ,['Age','Height','Weight']]
# Out:
#      Age  Height  Weight
# 0   21.0    1.62    64.0
# 1   21.0    1.52    56.0
# 2   23.0    1.80    77.0
# 3   27.0    1.80    87.0
# 4   22.0    1.78    89.8
# 5   29.0    1.62    53.0
# 6   23.0    1.50    55.0
# 7   22.0    1.64    53.0
# 8   24.0    1.78    64.0
# 9   22.0    1.72    68.0
# 10  26.0    1.85   105.0

# %%
obesity_data.loc[:,'Age':]
# Out:
#             Age    Height      Weight family_history FAVC  FCVC  NCP  \
# 0     21.000000  1.620000   64.000000            yes   no   2.0  3.0
# 1     21.000000  1.520000   56.000000            yes   no   3.0  3.0
# 2     23.000000  1.800000   77.000000            yes   no   2.0  3.0
# 3     27.000000  1.800000   87.000000             no   no   3.0  3.0
# 4     22.000000  1.780000   89.800000             no   no   2.0  1.0
# ...         ...       ...         ...            ...  ...   ...  ...
# 2106  20.976842  1.710730  131.408528            yes  yes   3.0  3.0
# 2107  21.982942  1.748584  133.742943            yes  yes   3.0  3.0
# 2108  22.524036  1.752206  133.689352            yes  yes   3.0  3.0
# 2109  24.361936  1.739450  133.346641            yes  yes   3.0  3.0
# 2110  23.664709  1.738836  133.472641            yes  yes   3.0  3.0
#
#            CAEC SMOKE      CH2O  SCC       FAF       TUE        CALC  \
# ...

# %%
obesity_data.loc[:,'Age':'FAF']
# Out:
#             Age    Height      Weight family_history FAVC  FCVC  NCP  \
# 0     21.000000  1.620000   64.000000            yes   no   2.0  3.0
# 1     21.000000  1.520000   56.000000            yes   no   3.0  3.0
# 2     23.000000  1.800000   77.000000            yes   no   2.0  3.0
# 3     27.000000  1.800000   87.000000             no   no   3.0  3.0
# 4     22.000000  1.780000   89.800000             no   no   2.0  1.0
# ...         ...       ...         ...            ...  ...   ...  ...
# 2106  20.976842  1.710730  131.408528            yes  yes   3.0  3.0
# 2107  21.982942  1.748584  133.742943            yes  yes   3.0  3.0
# 2108  22.524036  1.752206  133.689352            yes  yes   3.0  3.0
# 2109  24.361936  1.739450  133.346641            yes  yes   3.0  3.0
# 2110  23.664709  1.738836  133.472641            yes  yes   3.0  3.0
#
#            CAEC SMOKE      CH2O  SCC       FAF
# 0     Sometimes    no  2.000000   no  0.000000
# ...

# %%
obesity_data.iloc[0:10,0:5]
# Out:
#    Gender   Age  Height  Weight family_history
# 0  Female  21.0    1.62    64.0            yes
# 1  Female  21.0    1.52    56.0            yes
# 2    Male  23.0    1.80    77.0            yes
# 3    Male  27.0    1.80    87.0             no
# 4    Male  22.0    1.78    89.8             no
# 5    Male  29.0    1.62    53.0             no
# 6  Female  23.0    1.50    55.0            yes
# 7    Male  22.0    1.64    53.0             no
# 8    Male  24.0    1.78    64.0            yes
# 9    Male  22.0    1.72    68.0            yes

# %%
obesity_data.iloc[[0,10,30],[0,1,2]]
# Out:
#     Gender   Age  Height
# 0   Female  21.0    1.62
# 10    Male  26.0    1.85
# 30    Male  29.0    1.77

# %%
obesity_data.at[0,'Age']
# Out:
# 21.0

# %%
obesity_data.iloc[0,2]
# Out:
# 1.62

# %%
obesity_data.iat[0,4]
# Out:
# 'yes'

# %%
obesity_data.iloc[0:5,0:5]
# Out:
#    Gender   Age  Height  Weight family_history
# 0  Female  21.0    1.62    64.0            yes
# 1  Female  21.0    1.52    56.0            yes
# 2    Male  23.0    1.80    77.0            yes
# 3    Male  27.0    1.80    87.0             no
# 4    Male  22.0    1.78    89.8             no

# %%
obesity_data.loc[obesity_data['Weight']<50]
# Out:
#      Gender        Age    Height     Weight family_history FAVC      FCVC  \
# 36   Female  22.000000  1.560000  49.000000             no  yes  2.000000
# 37   Female  21.000000  1.600000  48.000000             no  yes  2.000000
# 51   Female  20.000000  1.500000  44.000000             no  yes  2.000000
# 60   Female  21.000000  1.550000  49.000000            yes  yes  2.000000
# 75   Female  23.000000  1.630000  45.000000            yes   no  3.000000
# ..      ...        ...       ...        ...            ...  ...       ...
# 737  Female  19.269079  1.580920  44.753943             no   no  3.000000
# 738  Female  19.946244  1.603435  45.000000             no   no  3.000000
# 739  Female  19.639431  1.535350  42.000000             no  yes  3.000000
# 740  Female  19.000000  1.531610  42.000000             no  yes  2.749268
# 741  Female  19.434709  1.525691  42.000000             no  yes  3.000000
#
#           NCP        CAEC SMOKE      CH2O  SCC       FAF       TUE       CALC  \
# ...

# %%
obesity_data.loc[(obesity_data['Weight']<50) & (obesity_data['Obesity']=='Normal_Weight')]
# Out:
#      Gender   Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 36   Female  22.0    1.56    49.0             no  yes   2.0  3.0   Sometimes
# 37   Female  21.0    1.60    48.0             no  yes   2.0  3.0   Sometimes
# 51   Female  20.0    1.50    44.0             no  yes   2.0  3.0   Sometimes
# 60   Female  21.0    1.55    49.0            yes  yes   2.0  3.0   Sometimes
# 94   Female  24.0    1.60    48.0             no  yes   3.0  3.0   Sometimes
# 113  Female  22.0    1.50    49.0            yes   no   2.0  1.0   Sometimes
# 156  Female  35.0    1.53    45.0            yes   no   3.0  3.0  Frequently
# 176  Female  18.0    1.57    48.0            yes  yes   3.0  1.0      Always
# 180  Female  18.0    1.58    48.0             no  yes   2.0  3.0   Sometimes
# 218  Female  21.0    1.50    42.3            yes   no   1.0  1.0   Sometimes
# 234  Female  19.0    1.59    49.0            yes  yes   2.0  1.0          no
# ...

# %%
obesity_data.loc[obesity_data['Obesity'].str.startswith('Normal')]
# Out:
#      Gender   Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 0    Female  21.0    1.62    64.0            yes   no   2.0  3.0   Sometimes
# 1    Female  21.0    1.52    56.0            yes   no   3.0  3.0   Sometimes
# 2      Male  23.0    1.80    77.0            yes   no   2.0  3.0   Sometimes
# 5      Male  29.0    1.62    53.0             no  yes   2.0  3.0   Sometimes
# 6    Female  23.0    1.50    55.0            yes  yes   3.0  3.0   Sometimes
# ..      ...   ...     ...     ...            ...  ...   ...  ...         ...
# 491    Male  25.0    1.66    68.0             no  yes   2.0  3.0   Sometimes
# 493    Male  20.0    1.80    65.0             no  yes   2.0  3.0  Frequently
# 494  Female  18.0    1.67    66.0             no  yes   3.0  3.0   Sometimes
# 495    Male  19.0    1.80    60.0            yes  yes   3.0  1.0      Always
# 497    Male  20.0    1.56    45.0             no   no   2.0  3.0   Sometimes
#
# ...

# %%
obesity_data.loc[obesity_data['Obesity'].str.endswith('Weight')]
# Out:
#      Gender        Age    Height     Weight family_history FAVC      FCVC  \
# 0    Female  21.000000  1.620000  64.000000            yes   no  2.000000
# 1    Female  21.000000  1.520000  56.000000            yes   no  3.000000
# 2      Male  23.000000  1.800000  77.000000            yes   no  2.000000
# 5      Male  29.000000  1.620000  53.000000             no  yes  2.000000
# 6    Female  23.000000  1.500000  55.000000            yes  yes  3.000000
# ..      ...        ...       ...        ...            ...  ...       ...
# 740  Female  19.000000  1.531610  42.000000             no  yes  2.749268
# 741  Female  19.434709  1.525691  42.000000             no  yes  3.000000
# 742    Male  18.000000  1.719827  52.289828            yes  yes  1.202075
# 743    Male  18.381382  1.722547  53.783977            yes  yes  2.000000
# 744    Male  18.000000  1.738702  50.248677            yes  yes  1.871213
#
#           NCP        CAEC SMOKE      CH2O  SCC       FAF       TUE  \
# ...

# %%
obesity_data.loc[:,'SMOKE']='yes'

# %%
obesity_data
# Out:
#       Gender        Age    Height      Weight family_history FAVC  FCVC  NCP  \
# 0     Female  21.000000  1.620000   64.000000            yes   no   2.0  3.0
# 1     Female  21.000000  1.520000   56.000000            yes   no   3.0  3.0
# 2       Male  23.000000  1.800000   77.000000            yes   no   2.0  3.0
# 3       Male  27.000000  1.800000   87.000000             no   no   3.0  3.0
# 4       Male  22.000000  1.780000   89.800000             no   no   2.0  1.0
# ...      ...        ...       ...         ...            ...  ...   ...  ...
# 2106  Female  20.976842  1.710730  131.408528            yes  yes   3.0  3.0
# 2107  Female  21.982942  1.748584  133.742943            yes  yes   3.0  3.0
# 2108  Female  22.524036  1.752206  133.689352            yes  yes   3.0  3.0
# 2109  Female  24.361936  1.739450  133.346641            yes  yes   3.0  3.0
# 2110  Female  23.664709  1.738836  133.472641            yes  yes   3.0  3.0
#
# ...

# %%
obesity_data.loc[:]
# Out:
#       Gender        Age    Height      Weight family_history FAVC  FCVC  NCP  \
# 0     Female  21.000000  1.620000   64.000000            yes   no   2.0  3.0
# 1     Female  21.000000  1.520000   56.000000            yes   no   3.0  3.0
# 2       Male  23.000000  1.800000   77.000000            yes   no   2.0  3.0
# 3       Male  27.000000  1.800000   87.000000             no   no   3.0  3.0
# 4       Male  22.000000  1.780000   89.800000             no   no   2.0  1.0
# ...      ...        ...       ...         ...            ...  ...   ...  ...
# 2106  Female  20.976842  1.710730  131.408528            yes  yes   3.0  3.0
# 2107  Female  21.982942  1.748584  133.742943            yes  yes   3.0  3.0
# 2108  Female  22.524036  1.752206  133.689352            yes  yes   3.0  3.0
# 2109  Female  24.361936  1.739450  133.346641            yes  yes   3.0  3.0
# 2110  Female  23.664709  1.738836  133.472641            yes  yes   3.0  3.0
#
# ...

# %%
obesity_data=pd.read_csv('./obesity_prediction.csv')

# %%
obesity_data.shape
# Out:
# (2111, 17)

# %%
obesity_data.loc[:]
# Out:
#       Gender        Age    Height      Weight family_history FAVC  FCVC  NCP  \
# 0     Female  21.000000  1.620000   64.000000            yes   no   2.0  3.0
# 1     Female  21.000000  1.520000   56.000000            yes   no   3.0  3.0
# 2       Male  23.000000  1.800000   77.000000            yes   no   2.0  3.0
# 3       Male  27.000000  1.800000   87.000000             no   no   3.0  3.0
# 4       Male  22.000000  1.780000   89.800000             no   no   2.0  1.0
# ...      ...        ...       ...         ...            ...  ...   ...  ...
# 2106  Female  20.976842  1.710730  131.408528            yes  yes   3.0  3.0
# 2107  Female  21.982942  1.748584  133.742943            yes  yes   3.0  3.0
# 2108  Female  22.524036  1.752206  133.689352            yes  yes   3.0  3.0
# 2109  Female  24.361936  1.739450  133.346641            yes  yes   3.0  3.0
# 2110  Female  23.664709  1.738836  133.472641            yes  yes   3.0  3.0
#
# ...

# %%
obesity_data.iloc[:]
# Out:
#       Gender        Age    Height      Weight family_history FAVC  FCVC  NCP  \
# 0     Female  21.000000  1.620000   64.000000            yes   no   2.0  3.0
# 1     Female  21.000000  1.520000   56.000000            yes   no   3.0  3.0
# 2       Male  23.000000  1.800000   77.000000            yes   no   2.0  3.0
# 3       Male  27.000000  1.800000   87.000000             no   no   3.0  3.0
# 4       Male  22.000000  1.780000   89.800000             no   no   2.0  1.0
# ...      ...        ...       ...         ...            ...  ...   ...  ...
# 2106  Female  20.976842  1.710730  131.408528            yes  yes   3.0  3.0
# 2107  Female  21.982942  1.748584  133.742943            yes  yes   3.0  3.0
# 2108  Female  22.524036  1.752206  133.689352            yes  yes   3.0  3.0
# 2109  Female  24.361936  1.739450  133.346641            yes  yes   3.0  3.0
# 2110  Female  23.664709  1.738836  133.472641            yes  yes   3.0  3.0
#
# ...

# %%
obesity_data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  21.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3    no   2.0   no  2.0  0.0  Frequently                Walking
# 4    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
obesity_data.loc[[2,3],['Height']]=1.81

# %%
obesity_data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  21.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.81    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.81    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3    no   2.0   no  2.0  0.0  Frequently                Walking
# 4    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
obesity_data.iloc[[0],[4]]="may be"

# %%
obesity_data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  21.0    1.62    64.0         may be   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.81    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.81    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3    no   2.0   no  2.0  0.0  Frequently                Walking
# 4    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
def increment_age_by_5(x):
    return x+5
    
obesity_data['Age']=obesity_data['Age'].apply(increment_age_by_5)

obesity_data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  26.0    1.62    64.0         may be   no   2.0  3.0  Sometimes
# 1  Female  26.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  28.0    1.81    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  32.0    1.81    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  27.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3    no   2.0   no  2.0  0.0  Frequently                Walking
# 4    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
obesity_data['Age']=obesity_data['Age'].apply(lambda x:x+5)

obesity_data['Age']
# Out:
# 0       31.000000
# 1       31.000000
# 2       33.000000
# 3       37.000000
# 4       32.000000
#           ...
# 2106    30.976842
# 2107    31.982942
# 2108    32.524036
# 2109    34.361936
# 2110    33.664709
# Name: Age, Length: 2111, dtype: float64

# %%
obesity_data['Age']=obesity_data['Age'].apply(lambda x :x-5)
obesity_data['Age']
# Out:
# 0       26.000000
# 1       26.000000
# 2       28.000000
# 3       32.000000
# 4       27.000000
#           ...
# 2106    25.976842
# 2107    26.982942
# 2108    27.524036
# 2109    29.361936
# 2110    28.664709
# Name: Age, Length: 2111, dtype: float64

# %%
obesity_data=pd.read_csv('./obesity_prediction.csv')

# %%
obesity_data['Age Category']=obesity_data['Age'].apply(lambda x :'very young' if x<30 else 'Not Young')

# %%
obesity_data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  21.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3    no   2.0   no  2.0  0.0  Frequently                Walking
# 4    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity Age Category
# 0        Normal_Weight   very young
# 1        Normal_Weight   very young
# ...

# %%
import numpy as np

# %%
obesity_data['New Age Category']=np.where(obesity_data['Age']<30 ,'Very Young','Not Yonge')

# %%
obesity_data.head(20)
# Out:
#     Gender   Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 0   Female  21.0    1.62    64.0            yes   no   2.0  3.0   Sometimes
# 1   Female  21.0    1.52    56.0            yes   no   3.0  3.0   Sometimes
# 2     Male  23.0    1.80    77.0            yes   no   2.0  3.0   Sometimes
# 3     Male  27.0    1.80    87.0             no   no   3.0  3.0   Sometimes
# 4     Male  22.0    1.78    89.8             no   no   2.0  1.0   Sometimes
# 5     Male  29.0    1.62    53.0             no  yes   2.0  3.0   Sometimes
# 6   Female  23.0    1.50    55.0            yes  yes   3.0  3.0   Sometimes
# 7     Male  22.0    1.64    53.0             no   no   2.0  3.0   Sometimes
# 8     Male  24.0    1.78    64.0            yes  yes   3.0  3.0   Sometimes
# 9     Male  22.0    1.72    68.0            yes  yes   2.0  3.0   Sometimes
# 10    Male  26.0    1.85   105.0            yes  yes   3.0  3.0  Frequently
# ...

# %%
obesity_data.insert(2,'BMI' , 20)

# %%
obesity_data.loc[:]
# Out:
#       Gender        Age  BMI    Height      Weight family_history FAVC  FCVC  \
# 0     Female  21.000000   20  1.620000   64.000000            yes   no   2.0
# 1     Female  21.000000   20  1.520000   56.000000            yes   no   3.0
# 2       Male  23.000000   20  1.800000   77.000000            yes   no   2.0
# 3       Male  27.000000   20  1.800000   87.000000             no   no   3.0
# 4       Male  22.000000   20  1.780000   89.800000             no   no   2.0
# ...      ...        ...  ...       ...         ...            ...  ...   ...
# 2106  Female  20.976842   20  1.710730  131.408528            yes  yes   3.0
# 2107  Female  21.982942   20  1.748584  133.742943            yes  yes   3.0
# 2108  Female  22.524036   20  1.752206  133.689352            yes  yes   3.0
# 2109  Female  24.361936   20  1.739450  133.346641            yes  yes   3.0
# 2110  Female  23.664709   20  1.738836  133.472641            yes  yes   3.0
#
# ...

# %%
obesity_data.drop(columns='BMI')
# Out:
#       Gender        Age    Height      Weight family_history FAVC  FCVC  NCP  \
# 0     Female  21.000000  1.620000   64.000000            yes   no   2.0  3.0
# 1     Female  21.000000  1.520000   56.000000            yes   no   3.0  3.0
# 2       Male  23.000000  1.800000   77.000000            yes   no   2.0  3.0
# 3       Male  27.000000  1.800000   87.000000             no   no   3.0  3.0
# 4       Male  22.000000  1.780000   89.800000             no   no   2.0  1.0
# ...      ...        ...       ...         ...            ...  ...   ...  ...
# 2106  Female  20.976842  1.710730  131.408528            yes  yes   3.0  3.0
# 2107  Female  21.982942  1.748584  133.742943            yes  yes   3.0  3.0
# 2108  Female  22.524036  1.752206  133.689352            yes  yes   3.0  3.0
# 2109  Female  24.361936  1.739450  133.346641            yes  yes   3.0  3.0
# 2110  Female  23.664709  1.738836  133.472641            yes  yes   3.0  3.0
#
# ...

# %%
obesity_data.head()
# Out:
#    Gender   Age  BMI  Height  Weight family_history FAVC  FCVC  NCP  \
# 0  Female  21.0   20    1.62    64.0            yes   no   2.0  3.0
# 1  Female  21.0   20    1.52    56.0            yes   no   3.0  3.0
# 2    Male  23.0   20    1.80    77.0            yes   no   2.0  3.0
# 3    Male  27.0   20    1.80    87.0             no   no   3.0  3.0
# 4    Male  22.0   20    1.78    89.8             no   no   2.0  1.0
#
#         CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity Age Category New Age Category
# ...

# %%
obesity_data.drop(columns='BMI',inplace=True)

# %%
obesity_data.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  21.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3    no   2.0   no  2.0  0.0  Frequently                Walking
# 4    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity Age Category New Age Category
# 0        Normal_Weight   very young       Very Young
# ...

# %%
obesity_data.insert(2,'BMI',obesity_data['Weight']/obesity_data['Height']**2)

# %%
obesity_data.head()
# Out:
#    Gender   Age        BMI  Height  Weight family_history FAVC  FCVC  NCP  \
# 0  Female  21.0  24.386526    1.62    64.0            yes   no   2.0  3.0
# 1  Female  21.0  24.238227    1.52    56.0            yes   no   3.0  3.0
# 2    Male  23.0  23.765432    1.80    77.0            yes   no   2.0  3.0
# 3    Male  27.0  26.851852    1.80    87.0             no   no   3.0  3.0
# 4    Male  22.0  28.342381    1.78    89.8             no   no   2.0  1.0
#
#         CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity Age Category New Age Category
# ...

# %%
df1=pd.DataFrame({
   'id' :[1,2,3,4],
    'name':['Abhi','Amit' ,'Cloud','GenAI']    
})

df2= pd.DataFrame({
   'id' : [3,4,5,6],
    'course':['GenAi','LLD','MLD','LLM']

})

inner_result=pd.merge(df1,df2,how='inner',on='id')

inner_result
# Out:
#    id   name course
# 0   3  Cloud  GenAi
# 1   4  GenAI    LLD

# %%
outer_join=pd.merge(df1,df2,how='outer',on='id')
outer_join
# Out:
#    id   name course
# 0   1   Abhi    NaN
# 1   2   Amit    NaN
# 2   3  Cloud  GenAi
# 3   4  GenAI    LLD
# 4   5    NaN    MLD
# 5   6    NaN    LLM

# %%
left_result=pd.merge(df1,df2,how='left', on ='id')
left_result
# Out:
#    id   name course
# 0   1   Abhi    NaN
# 1   2   Amit    NaN
# 2   3  Cloud  GenAi
# 3   4  GenAI    LLD

# %%
result_concat= pd.concat([df1,df2],axis=0,ignore_index=True)
result_concat
# Out:
#    id   name course
# 0   1   Abhi    NaN
# 1   2   Amit    NaN
# 2   3  Cloud    NaN
# 3   4  GenAI    NaN
# 4   3    NaN  GenAi
# 5   4    NaN    LLD
# 6   5    NaN    MLD
# 7   6    NaN    LLM

# %%
result_concat= pd.concat([df1,df2],axis=1)
result_concat
# Out:
#    id   name  id course
# 0   1   Abhi   3  GenAi
# 1   2   Amit   4    LLD
# 2   3  Cloud   5    MLD
# 3   4  GenAI   6    LLM

# %%
result_concat.isna()
# Out:
#       id   name     id  course
# 0  False  False  False   False
# 1  False  False  False   False
# 2  False  False  False   False
# 3  False  False  False   False

# %%
result_concat= pd.concat([df1,df2],axis=0,ignore_index=True)
result_concat
# Out:
#    id   name course
# 0   1   Abhi    NaN
# 1   2   Amit    NaN
# 2   3  Cloud    NaN
# 3   4  GenAI    NaN
# 4   3    NaN  GenAi
# 5   4    NaN    LLD
# 6   5    NaN    MLD
# 7   6    NaN    LLM

# %%
result_concat.isna()
# Out:
#       id   name  course
# 0  False  False    True
# 1  False  False    True
# 2  False  False    True
# 3  False  False    True
# 4  False   True   False
# 5  False   True   False
# 6  False   True   False
# 7  False   True   False

# %%
result_concat.isna().sum()
# Out:
# id        0
# name      4
# course    4
# dtype: int64

# %%
obesity_data.loc[0,'Age']=np.nan

# %%
obesity_data.head()
# Out:
#    Gender   Age        BMI  Height  Weight family_history FAVC  FCVC  NCP  \
# 0  Female   NaN  24.386526    1.62    64.0            yes   no   2.0  3.0
# 1  Female  21.0  24.238227    1.52    56.0            yes   no   3.0  3.0
# 2    Male  23.0  23.765432    1.80    77.0            yes   no   2.0  3.0
# 3    Male  27.0  26.851852    1.80    87.0             no   no   3.0  3.0
# 4    Male  22.0  28.342381    1.78    89.8             no   no   2.0  1.0
#
#         CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity Age Category New Age Category
# ...

# %%
obesity_data.loc[0,'Age']=np.nan
obesity_data.loc[0 ,'SMOKE']=np.nan
obesity_data.loc[2,'Age']=np.nan

# %%
obesity_data.fillna(0)
# Out:
#       Gender        Age        BMI    Height      Weight family_history FAVC  \
# 0     Female   0.000000  24.386526  1.620000   64.000000            yes   no
# 1     Female  21.000000  24.238227  1.520000   56.000000            yes   no
# 2       Male   0.000000  23.765432  1.800000   77.000000            yes   no
# 3       Male  27.000000  26.851852  1.800000   87.000000             no   no
# 4       Male  22.000000  28.342381  1.780000   89.800000             no   no
# ...      ...        ...        ...       ...         ...            ...  ...
# 2106  Female  20.976842  44.901475  1.710730  131.408528            yes  yes
# 2107  Female  21.982942  43.741923  1.748584  133.742943            yes  yes
# 2108  Female  22.524036  43.543817  1.752206  133.689352            yes  yes
# 2109  Female  24.361936  44.071535  1.739450  133.346641            yes  yes
# 2110  Female  23.664709  44.144338  1.738836  133.472641            yes  yes
#
# ...

# %%
obesity_data['Age']=obesity_data['Age'].fillna(20)

# %%
obesity_data.head()
# Out:
#    Gender   Age        BMI  Height  Weight family_history FAVC  FCVC  NCP  \
# 0  Female  20.0  24.386526    1.62    64.0            yes   no   2.0  3.0
# 1  Female  21.0  24.238227    1.52    56.0            yes   no   3.0  3.0
# 2    Male  20.0  23.765432    1.80    77.0            yes   no   2.0  3.0
# 3    Male  27.0  26.851852    1.80    87.0             no   no   3.0  3.0
# 4    Male  22.0  28.342381    1.78    89.8             no   no   2.0  1.0
#
#         CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  Sometimes   NaN   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity Age Category New Age Category
# ...

# %%
obesity_data.loc[0,'Age']=np.nan
obesity_data['Age']=obesity_data['Age'].fillna(obesity_data['Age'].mean())

# %%
obesity_data.head()
# Out:
#    Gender        Age        BMI  Height  Weight family_history FAVC  FCVC  \
# 0  Female  24.312748  24.386526    1.62    64.0            yes   no   2.0
# 1  Female  21.000000  24.238227    1.52    56.0            yes   no   3.0
# 2    Male  20.000000  23.765432    1.80    77.0            yes   no   2.0
# 3    Male  27.000000  26.851852    1.80    87.0             no   no   3.0
# 4    Male  22.000000  28.342381    1.78    89.8             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes   NaN   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS              Obesity Age Category New Age Category
# 0  Public_Transportation        Normal_Weight   very young       Very Young
# ...

# %%
obesity_data.groupby('Gender')['Height'].mean()
# Out:
# Gender
# Female    1.643298
# Male      1.758690
# Name: Height, dtype: float64

# %%
obesity_data.groupby('Gender')['Height'].sum()
# Out:
# Gender
# Female    1713.959615
# Male      1878.281278
# Name: Height, dtype: float64

# %%
obesity_data.groupby('Gender')['Height'].agg(['sum','mean'])
# Out:
#                 sum      mean
# Gender
# Female  1713.959615  1.643298
# Male    1878.281278  1.758690
